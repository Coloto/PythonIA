# %%
import pandas as pd

productos=pd.read_csv('products.csv')
# print(productos)
bins= [0,50,100,500]
grupos=["stock critico","stock-normal","stock"]
df=productos[["unitsInStock"]]
df["unitsInStock"]=pd.cut(df["unitsInStock"],bins,grupos)
# print(df["unitsInStock"])
# Reto: dibuja un gráfico en donde muestres info en base a esos rangos/grupos.

df.unitsInStock.value_counts().plot.pie()
plot.show()
# Out:
# C:\Users\Tecnicos\AppData\Local\Temp\ipykernel_13804\636083419.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["unitsInStock"]=pd.cut(df["unitsInStock"],bins,grupos)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13804\636083419.py in <module>
#      11
#      12 df.unitsInStock.value_counts().plot.pie()
# ---> 13 plot.show()
#
# NameError: name 'plot' is not defined

# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame()
date = [datetime.datetime(2018, 1, 1) + datetime.timedelta(days=x) for x in range(0, 365)]
value = list(np.random.randint(low=0, high=100, size=365))
df['date'] = pd.to_datetime(date)
df.index = df['date']
df['value'] = value
# print(df['date'])
# print(df['value'])
print(df.resample('Q').mean())

# Reto. diseña un gráfico de barras para mostrar la media de datos por trimestre

x=df.groupby(df['date'].dt.quarter).mean()
x.plot.barh()
# Out:
#                 value
# date
# 2018-03-31  44.744444
# 2018-06-30  49.945055
# 2018-09-30  45.391304
# 2018-12-31  54.619565
